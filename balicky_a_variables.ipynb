# %%
import os

# %%
path_to_data = os.getenv('PATH_TO_DATA_OSN_v2024_2_3')

# %%
print(path_to_data)
# Out:
# C:\Users\hunakj\health.gov.sk\IZA - Cestovanie za ZS\2023\Data inputs\osn_vsetka_starostlivost_2023_ms_v2024.2.3.csv
